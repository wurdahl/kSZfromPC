# %%
import healpy as hp
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# %%
map = hp.read_map('./MAPS/lensedOverdensity_NS_1024_R_2048_P_2560_DV_256.fits')

# %%
proj = hp.mollview(map)

# %%
proj.savefig("./example.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ba4ab73e553e> in <module>
# ----> 1 proj.savefig("./example.png")
#
# AttributeError: 'NoneType' object has no attribute 'savefig'
