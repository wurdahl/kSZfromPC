# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np
import healpy as hp

# %%
overdensity = hp.read_map("MAPS/overdensity_NS_1024_R_512_P_768_DV_32.fits")
hp.mollview(overdensity,xsize=6400, max=4)

# %%
plt.plot(hp.sphtfunc.anafast(overdensity)[0:50]);

# %%
kSZ = hp.read_map("MAPS/kSZ_NS_1024_R_512_P_768_DV_32.fits")
hp.mollview(kSZ,xsize=6400, min=-1.5*10**-6,max=1.5*10**-6)

# %%
from scipy import stats
stats.mode(kSZ)
# Out:
# ModeResult(mode=array([-0.]), count=array([1597927]))

# %%
stats.mode(kSZ)[1][0]/len(kSZ)
# Out:
# 0.12699182828267416

# %%
plt.hist(kSZ,bins = np.linspace(-1*10**-6,1*10**-6));

# %%
plt.plot(hp.sphtfunc.anafast(kSZ)[0:30]);

# %%
convergence = hp.read_map("MAPS/convergence_NS_1024_R_512_P_768_DV_32.fits")
hp.mollview(convergence,xsize=3200,max=1)

# %%
hp.newvisufunc.projview(convergence,max=1,xsize=3200);

# %%
plt.plot(hp.sphtfunc.anafast(convergence)[0:75]);
