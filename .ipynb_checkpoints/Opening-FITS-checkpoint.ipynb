# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np
import healpy as hp

# %%
densityCount = hp.read_map("DensityCount.fits")

# %%
plt.hist(densityCount,bins=np.linspace(0,20));

# %%
hp.mollview(densityCount,xsize=3200, max=200)

# %%
o = hp.read_map("overdensity.fits")
hp.mollview(o,xsize=3200, max=8)

# %%
kSZ = hp.read_map("kSZ.fits")
hp.mollview(kSZ,xsize=3200, min=-2, max=2)

# %%
plt.hist(kSZ,bins=np.linspace(-5,5));
