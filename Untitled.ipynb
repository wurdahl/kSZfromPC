# %%
import healpy as hp
import numpy as np

# %%
nside = 3

# %%
map = np.random.rand(12*nside**2)

# %%
len(map)
# Out:
# 108

# %%
hp.mollview(map);

# %%
nside=2

# %%
map2 = np.random.rand(12*nside**2)

# %%
hp.mollview

# %%
ps = hp.anafast(map)

# %%
map2 = hp.synfast(ps,nside=nside)

# %%
hp.mollview(map2)

# %%
len(map2)
# Out:
# 122412
